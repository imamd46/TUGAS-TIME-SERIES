# %% [markdown]
# <a href="https://colab.research.google.com/github/imamd46/TUGAS-TIME-SERIES/blob/main/TIME_SERIES_(BASIC)_M_Imam_Darmawansyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Load Packages

# %%
# utilities packages
import datetime

# data wrangling and transformation package
import numpy as np
import pandas as pd
import statsmodels.api as sm

# data visualization package
import matplotlib.pyplot as plt
import seaborn as sns

# time series modeling
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot

# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
task_1_1 = pd.read_csv("task_1_1.csv")
task_1_2 = pd.read_csv("task_1_2.csv")
task_1_3 = pd.read_csv("task_1_3.csv")
task_1_4 = pd.read_csv("task_1_4.csv")
task_1_5 = pd.read_csv("task_1_5.csv")
task_1_6 = pd.read_csv("task_1_6.csv")
task_1_7 = pd.read_csv("task_1_7.csv")
task_1_8 = pd.read_csv("task_1_8.csv")
task_1_9 = pd.read_csv("task_1_9.csv")
task_1_10 = pd.read_csv("task_1_10.csv")

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# Task 1

# %%
# check the first 5 rows
task_1_1.head()
# Out:
#    index     value
# 0    101  1.323913
# 1    102  1.197747
# 2    103 -0.951691
# 3    104  1.904784
# 4    105 -0.551699

# %%
# check data structure
task_1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %% [markdown]
# Task 2

# %%
# check the first 5 rows
task_1_2.head()
# Out:
#    index     value
# 0    101  2.362450
# 1    102  3.849367
# 2    103  2.421574
# 3    104  5.052382
# 4    105  4.103413

# %%
# check data structure
task_1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %% [markdown]
# Task 3

# %%
# check the first 5 rows
task_1_3.head()
# Out:
#    index     value
# 0    101 -1.405059
# 1    102  0.471055
# 2    103 -0.006376
# 3    104  1.030057
# 4    105  0.207344

# %%
# check data structure
task_1_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    int64
#  1   value   100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %% [markdown]
# Task 4

# %%
# check the first 5 rows
task_1_4.head()
# Out:
#    index      value
# 0  1 Jan  14.346754
# 1  1 Feb  14.877385
# 2  1 Mar  16.630073
# 3  1 Apr  18.742186
# 4  1 Mei  17.657716

# %%
# check data structure
task_1_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    object
#  1   value   100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# Task 5

# %%
# check the first 5 rows
task_1_5.head()
# Out:
#    index     value
# 0  1 Jan  3.010220
# 1  1 Feb  0.500811
# 2  1 Mar  0.430380
# 3  1 Apr  3.807056
# 4  1 Mei  1.347951

# %%
# check data structure
task_1_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    object
#  1   value   100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# Task 6

# %%
# check the first 5 rows
task_1_6.head()
# Out:
#    index     value
# 0  1 Jan  0.183993
# 1  1 Feb  1.712356
# 2  1 Mar  2.761235
# 3  1 Apr  2.977488
# 4  1 Mei  1.681076

# %%
# check data structure
task_1_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    object
#  1   value   100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# Task 7

# %%
# check the first 5 rows
task_1_7.head()
# Out:
#    index     value
# 0  1 Jan  0.167240
# 1  1 Feb  4.048346
# 2  1 Mar  0.898316
# 3  1 Apr -5.074511
# 4  1 Mei -3.305332

# %%
# check data structure
task_1_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   100 non-null    object
#  1   value   100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# Task 8

# %%
# check the first 5 rows
task_1_8.head()
# Out:
#    index   x
# 0      1  13
# 1      2  14
# 2      3   8
# 3      4  10
# 4      5  16

# %%
# check data structure
task_1_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   99 non-null     int64
#  1   x       99 non-null     int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %% [markdown]
# Task 9

# %%
# check the first 5 rows
task_1_9.head()
# Out:
#    index       x
# 0      1   97.85
# 1      2  104.64
# 2      3   94.36
# 3      4   98.05
# 4      5   95.85

# %%
# check data structure
task_1_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   508 non-null    int64
#  1   x       508 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 8.1 KB

# %% [markdown]
# Task 10

# %%
# check the first 5 rows
task_1_10.head()
# Out:
#    index          x
# 0      1  11.158810
# 1      2   9.917591
# 2      3   9.824230
# 3      4   8.855909
# 4      5   9.264166

# %%
# check data structure
task_1_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   150 non-null    int64
#  1   x       150 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.5 KB

# %% [markdown]
# # ACF & PACF

# %% [markdown]
# ## Task 1

# %%
plot_series(task_1_1['value']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3c0ce3bf24ea> in <module>()
# ----> 1 plot_series(task_1_1['value']);
#
# NameError: name 'plot_series' is not defined

# %%
plot_acf(task_1_1['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_1['value']).set_size_inches((14,5));

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: tidak ada lag yang signifikan
# *   PACF: terdapat lag signifikan pada lag 20
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 2

# %%
plot_series(task_1_2['value']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2a3411ac173a> in <module>()
# ----> 1 plot_series(task_1_2['value']);
#
# NameError: name 'plot_series' is not defined

# %%
plot_acf(task_1_2['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_2['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat Exponential decay sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 3

# %%
plot_series(task_1_3['value']);

# %%
plot_acf(task_1_3['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_3['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: tidak ada lag yang signifikan
# *   PACF: tidak ada lag yang signifikan
# *   maka jenis time series nya adalah random walk/white noise

# %% [markdown]
# ## Task 4

# %%
plot_series(task_1_4['value']);

# %%
plot_acf(task_1_4['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_4['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat Exponential decay sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 5

# %%
plot_series(task_1_5['value']);

# %%
plot_acf(task_1_5['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_5['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat damped sinusoidal sehingga dapat diabaikan
# *   PACF: terdapat eksponential damped maka dapat diabaikan
# *   maka jenis time series nya adalah random walk/white noise

# %% [markdown]
# ## Task 6

# %%
plot_series(task_1_6['value']);

# %%
plot_acf(task_1_6['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_6['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
# *   ACF: Terdapat damped sinusoidal sehingga dapat diabaikan
# *   PACF: terdapat eksponential damped maka dapat diabaikan
# *   maka jenis time series nya adalah random walk/white noise

# %% [markdown]
# ## Task 7

# %%
plot_series(task_1_7['value']);

# %%
plot_acf(task_1_7['value']).set_size_inches((14,5));

# %%
plot_pacf(task_1_7['value']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat Exponential decay sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 8

# %%
plot_series(task_1_8['x']);

# %%
plot_acf(task_1_8['x']).set_size_inches((14,5));

# %%
plot_pacf(task_1_8['x']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat damped sinusodial sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 9

# %%
plot_series(task_1_9['x']);

# %%
plot_acf(task_1_9['x']).set_size_inches((14,5));

# %%
plot_pacf(task_1_9['x']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat Exponential decay sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)

# %% [markdown]
# ## Task 10

# %%
plot_series(task_1_10['x']);

# %%
plot_acf(task_1_10['x']).set_size_inches((14,5));

# %%
plot_pacf(task_1_10['x']).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# **SIMPULAN**
#
# *   ACF: Terdapat Exponential decay sehingga dapat diabaikan
# *   PACF: terdapat lag signifikan pada lag 1
# *   maka jenis time series nya adalah (AR)
